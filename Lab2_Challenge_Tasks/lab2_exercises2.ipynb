# %%
engineer_name = "KIM HARRIE"
first_letter = engineer_name[0]
ascii_value = ord(first_letter)

print("ASCII:", ascii_value)

SEED_NUM = 7
loops = 10

verification_hash = (75 * 7)
print("Verification Hash", verification_hash)
# Out:
# ASCII: 75
# Verification Hash 525
